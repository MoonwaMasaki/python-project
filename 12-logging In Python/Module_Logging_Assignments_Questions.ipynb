# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging

# %% [markdown]
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.

# %%
import logging

def basic_logger():
    logging.basicConfig(filename='app.log', level=logging.DEBUG)
    logging.debug('This is a debug message')
    logging.info('This is an info message')
    logging.warning('This is a warning message')
    logging.error('This is an error message')
    logging.critical('This is a critical message')

# Test the function
basic_logger()

# %% [markdown]
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

# %%
def logger_with_handlers():
    logger = logging.getLogger('my_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('app.log')
    console_handler = logging.StreamHandler()
    
    file_handler.setLevel(logging.DEBUG)
    console_handler.setLevel(logging.DEBUG)
    
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_handlers()
# Out:
# 2025-08-21 20:03:43,527 - my_logger - DEBUG - This is a debug message
# 2025-08-21 20:03:43,528 - my_logger - INFO - This is an info message
# 2025-08-21 20:03:43,529 - my_logger - WARNING - This is a warning message
# 2025-08-21 20:03:43,530 - my_logger - ERROR - This is an error message
# 2025-08-21 20:03:43,531 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different logging levels for the file and console handlers.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

# %%
def logger_with_custom_format():
    logger = logging.getLogger('custom_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('custom_app.log')
    console_handler = logging.StreamHandler()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_custom_format()
# Out:
# 2025-08-21 20:24:16,353 - DEBUG - This is a debug message
# 2025-08-21 20:24:16,355 - INFO - This is an info message
# 2025-08-21 20:24:16,356 - WARNING - This is a warning message
# 2025-08-21 20:24:16,356 - ERROR - This is an error message
# 2025-08-21 20:24:16,357 - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different formats for the file and console handlers.

# %%
def logger_with_different_formats():
    logger = logging.getLogger('multi_format_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('multi_format_app.log')
    console_handler = logging.StreamHandler()
    
    file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(file_formatter)
    console_handler.setFormatter(console_formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_different_formats()
# Out:
# 2025-08-21 20:24:32,613 - DEBUG - This is a debug message
# 2025-08-21 20:24:32,615 - INFO - This is an info message
# 2025-08-21 20:24:32,615 - WARNING - This is a warning message
# 2025-08-21 20:24:32,616 - ERROR - This is an error message
# 2025-08-21 20:24:32,616 - CRITICAL - This is a critical message

# %% [markdown]
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.

# %%
from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
    logger = logging.getLogger('rotating_logger')
    logger.setLevel(logging.DEBUG)
    
    rotating_handler = RotatingFileHandler('rotating_app.log', maxBytes=2000, backupCount=5)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    rotating_handler.setFormatter(formatter)
    
    logger.addHandler(rotating_handler)
    
    for i in range(100):
        logger.debug('This is debug message number {}'.format(i))

# Test the function
logger_with_rotating_file_handler()

# %% [markdown]
# 2. Modify the function to keep a specified number of backup log files.

# %%
# The modification is already included in the above function with backupCount=

# %% [markdown]
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.

# %%
def log_exception():
    logger = logging.getLogger('exception_logger')
    logger.setLevel(logging.ERROR)
    
    file_handler = logging.FileHandler('exception_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    try:
        1 / 0
    except Exception as e:
        logger.exception("An exception occurred")

# Test the function
log_exception()

# %% [markdown]
# 2. Modify the function to log the stack trace at the ERROR level.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.

# %%
def logger_with_context():
    logger = logging.getLogger('context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    def test_func():
        logger.debug('This is a debug message')
        logger.info('This is an info message')
        logger.warning('This is a warning message')
        logger.error('This is an error message')
        logger.critical('This is a critical message')
    
    test_func()

# Test the function
logger_with_context()

# %% [markdown]
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).

# %%
def logger_with_additional_context(user_id, session_id):
    logger = logging.getLogger('additional_context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('additional_context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d - UserID: %(user_id)s - SessionID: %(session_id)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    extra = {'user_id': user_id, 'session_id': session_id}
    
    def test_func():
        logger.debug('This is a debug message', extra=extra)
        logger.info('This is an info message', extra=extra)
        logger.warning('This is a warning message', extra=extra)
        logger.error('This is an error message', extra=extra)
        logger.critical('This is a critical message', extra=extra)
    
    test_func()

# Test the function
logger_with_additional_context('user123', 'session456')

# %% [markdown]
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.

# %%
import logging.config

def configure_logging_with_dict():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            },
            'detailed': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'dict_config_app.log',
                'formatter': 'detailed',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)
    logger = logging.getLogger('')
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
configure_logging_with_dict()
# Out:
# 2025-08-21 20:27:28,483 - root - DEBUG - This is a debug message
# 2025-08-21 20:27:28,484 - root - INFO - This is an info message
# 2025-08-21 20:27:28,485 - root - WARNING - This is a warning message
# 2025-08-21 20:27:28,485 - root - ERROR - This is an error message
# 2025-08-21 20:27:28,486 - root - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the dictionary to include different logging levels and formats for each handler.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.

# %%
import logging
from module_a import module_a_function
from module_b import module_b_function

def setup_logging():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'multi_module_app.log',
                'formatter': 'default',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)

# Main script
if __name__ == '__main__':
    setup_logging()
    logger = logging.getLogger(__name__)
    logger.info('Main module started')
    module_a_function()
    module_b_function()
    logger.info('Main module finished')
# Out:
# 2025-08-21 20:31:02,779 - __main__ - INFO - Main module started
# 2025-08-21 20:31:02,780 - module_a - INFO - Module A function started
# 2025-08-21 20:31:02,780 - module_a - DEBUG - This is a debug message from Module A
# 2025-08-21 20:31:02,781 - module_a - INFO - Module A function finished
# 2025-08-21 20:31:02,782 - module_b - INFO - Module B function started
# 2025-08-21 20:31:02,783 - module_b - DEBUG - This is a debug message from Module B
# 2025-08-21 20:31:02,783 - module_b - INFO - Module B function finished
# 2025-08-21 20:31:02,783 - __main__ - INFO - Main module finished

# %% [markdown]
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.

# %%
# The modification is already included in the above scripts. Each module's logger messages propagate to the root logger.

# %% [markdown]
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).

# %%
import logging
import time
from logging.handlers import RotatingFileHandler

def benchmark_logging_performance():
    logger = logging.getLogger('performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler
    file_handler = logging.FileHandler('performance_file.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # Console handler
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.DEBUG)
    logger.addHandler(console_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Console handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(console_handler)

    # Rotating file handler
    rotating_handler = RotatingFileHandler('performance_rotating.log', maxBytes=2000, backupCount=5)
    rotating_handler.setLevel(logging.DEBUG)
    logger.addHandler(rotating_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Rotating file handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(rotating_handler)

# Test the function
benchmark_logging_performance()
# Out:
# 2025-08-21 20:31:41,308 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,309 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,310 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,310 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,311 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,311 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,312 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,312 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,312 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,313 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,313 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,314 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,314 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,315 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,316 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,316 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,316 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,316 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,317 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,317 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,317 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,317 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,318 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,318 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,318 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,319 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,319 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,319 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,319 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,320 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,320 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41,320 - performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:31:41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 46
#      43     logger.removeHandler(rotating_handler)
#      45 # Test the function
# ---> 46 benchmark_logging_performance()
#
# Cell In[12], line 40, in benchmark_logging_performance()
#      38 start_time = time.time()
#      39 for i in range(10000):
# ---> 40     logger.debug('This is a debug message')
#      41 end_time = time.time()
#      42 print('Rotating file handler logging time: {} seconds'.format(end_time - start_time))
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1510, in Logger.debug(self, msg, *args, **kwargs)
#    1501 """
#    1502 Log 'msg % args' with severity 'DEBUG'.
#    1503
#    (...)   1507 logger.debug("Houston, we have a %s", "thorny problem", exc_info=True)
#    1508 """
#    1509 if self.isEnabledFor(DEBUG):
# -> 1510     self._log(DEBUG, msg, args, **kwargs)
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1667, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1664         exc_info = sys.exc_info()
#    1665 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1666                          exc_info, func, extra, sinfo)
# -> 1667 self.handle(record)
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1686, in Logger.handle(self, record)
#    1684     if isinstance(maybe_record, LogRecord):
#    1685         record = maybe_record
# -> 1686     self.callHandlers(record)
#    1687 finally:
#    1688     self._tls.in_progress = False
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1744, in Logger.callHandlers(self, record)
#    1742     found = found + 1
#    1743     if record.levelno >= hdlr.level:
# -> 1744         hdlr.handle(record)
#    1745 if not c.propagate:
#    1746     c = None    #break out
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1027, in Handler.handle(self, record)
#    1025 if rv:
#    1026     with self.lock:
# -> 1027         self.emit(record)
#    1028 return rv
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1155, in StreamHandler.emit(self, record)
#    1153     # issue 35046: merged two stream.writes into one.
#    1154     stream.write(msg + self.terminator)
# -> 1155     self.flush()
#    1156 except RecursionError:  # See issue 36272
#    1157     raise
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1137, in StreamHandler.flush(self)
#    1135 with self.lock:
#    1136     if self.stream and hasattr(self.stream, "flush"):
# -> 1137         self.stream.flush()
#
# File /opt/miniconda3/lib/python3.13/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File /opt/miniconda3/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /opt/miniconda3/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# 2. Modify the script to compare the performance of logging with and without message formatting.

# %%
def benchmark_logging_formatting_performance():
    logger = logging.getLogger('formatting_performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler without formatting
    file_handler = logging.FileHandler('performance_no_format.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time without formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # File handler with formatting
    file_handler = logging.FileHandler('performance_with_format.log')
    file_handler.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time with formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

# Test the function
benchmark_logging_formatting_performance()
# Out:
# 2025-08-21 20:32:41,875 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,876 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,877 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,877 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,878 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,879 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,879 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,880 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,880 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,880 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,880 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,881 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,881 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,881 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,881 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,882 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,882 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,882 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,882 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,883 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,883 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,883 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,883 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,884 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,884 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,884 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,884 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,885 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,885 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,885 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,885 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,886 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,886 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,886 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,886 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,887 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,887 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,887 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,887 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,888 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,888 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,889 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,889 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,889 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,889 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,889 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,890 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,890 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,890 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,890 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,891 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,891 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,891 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,891 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,891 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,892 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,892 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,892 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,892 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,892 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,893 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,893 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,893 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,893 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,894 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,894 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,894 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,894 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,894 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,895 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,895 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,895 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,895 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,895 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,896 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,896 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,896 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,896 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,896 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,897 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,897 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,897 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,897 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,897 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,898 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,898 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,898 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,898 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,899 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,899 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,899 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,899 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,899 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,900 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,900 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,900 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,900 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,901 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,901 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,901 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,901 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,901 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,902 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,903 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,903 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,903 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,903 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,903 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,904 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,905 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,906 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,906 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,906 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,906 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,906 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,907 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,908 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,908 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,908 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,908 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,909 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,910 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,910 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,910 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,910 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,910 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,911 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,912 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,913 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,914 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,915 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,915 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,915 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,915 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,916 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,916 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,916 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,917 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,918 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,919 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,920 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,921 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,922 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,923 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,924 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,925 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,926 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,926 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,926 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,926 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,926 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,927 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,928 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,929 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,930 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,931 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,932 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,932 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,932 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,932 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,933 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,933 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,933 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,933 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,933 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,934 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,934 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,934 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,934 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,934 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,935 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41,936 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:41
- formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:48,425 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:48,426 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:48,426 - formatting_performance_logger - DEBUG - This is a debug message
# 2025-08-21 20:32:48,426 - formatting_performance_logger - DEBUG - This is a debug message
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 32
#      29     logger.removeHandler(file_handler)
#      31 # Test the function
# ---> 32 benchmark_logging_formatting_performance()
#
# Cell In[13], line 26, in benchmark_logging_formatting_performance()
#      24 start_time = time.time()
#      25 for i in range(10000):
# ---> 26     logger.debug('This is a debug message')
#      27 end_time = time.time()
#      28 print('File handler logging time with formatting: {} seconds'.format(end_time - start_time))
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1510, in Logger.debug(self, msg, *args, **kwargs)
#    1501 """
#    1502 Log 'msg % args' with severity 'DEBUG'.
#    1503
#    (...)   1507 logger.debug("Houston, we have a %s", "thorny problem", exc_info=True)
#    1508 """
#    1509 if self.isEnabledFor(DEBUG):
# -> 1510     self._log(DEBUG, msg, args, **kwargs)
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1667, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1664         exc_info = sys.exc_info()
#    1665 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1666                          exc_info, func, extra, sinfo)
# -> 1667 self.handle(record)
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1686, in Logger.handle(self, record)
#    1684     if isinstance(maybe_record, LogRecord):
#    1685         record = maybe_record
# -> 1686     self.callHandlers(record)
#    1687 finally:
#    1688     self._tls.in_progress = False
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1744, in Logger.callHandlers(self, record)
#    1742     found = found + 1
#    1743     if record.levelno >= hdlr.level:
# -> 1744         hdlr.handle(record)
#    1745 if not c.propagate:
#    1746     c = None    #break out
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1027, in Handler.handle(self, record)
#    1025 if rv:
#    1026     with self.lock:
# -> 1027         self.emit(record)
#    1028 return rv
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1265, in FileHandler.emit(self, record)
#    1263         self.stream = self._open()
#    1264 if self.stream:
# -> 1265     StreamHandler.emit(self, record)
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1155, in StreamHandler.emit(self, record)
#    1153     # issue 35046: merged two stream.writes into one.
#    1154     stream.write(msg + self.terminator)
# -> 1155     self.flush()
#    1156 except RecursionError:  # See issue 36272
#    1157     raise
#
# File /opt/miniconda3/lib/python3.13/logging/__init__.py:1137, in StreamHandler.flush(self)
#    1135 with self.lock:
#    1136     if self.stream and hasattr(self.stream, "flush"):
# -> 1137         self.stream.flush()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.

# %%
import logging.config

def setup_logging_from_file():
    logging.config.fileConfig('logging.conf')
    logger = logging.getLogger(__name__)
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
setup_logging_from_file()

# %% [markdown]
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
# The modification is already included in the above configuration file.
